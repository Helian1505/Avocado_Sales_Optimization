# %% [markdown]
# <a href="https://colab.research.google.com/github/Helian1505/Avocado_Sales_Optimization/blob/main/Avocado_hass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Avocado Quality ROI — does grading technology pay for itself?
#
# A Colombian retail chain loses Hass avocado sales when the fruit on the shelf is too firm:
# the shopper picks it up, puts it back, and leaves. That loss never shows up in shrinkage
# reports, because the fruit was never damaged — the *demand* was.
#
# This notebook prices that invisible loss and tests whether a COP 150M automated grading
# investment is worth making.
#
# **How to read this notebook**
#
# 1. **The dataset is committed, not regenerated.** `data/avocado_simulated_data.csv` is one
#    simulated trading year and it is the canonical input: every figure in the README comes
#    from it. It was originally drawn without a random seed, so it cannot be reproduced by
#    re-running the generator — it is version-controlled instead.
# 2. **The generator is still here**, seeded and reproducible, and it produces a *different*
#    year. That is the point of section 4: one year is a draw, not a fact.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from dataclasses import dataclass
from pathlib import Path
from matplotlib.patches import FancyBboxPatch

pd.options.display.float_format = "{:,.2f}".format

# ── Model assumptions: Colombian large-format retail, Hass avocado ──────────────
UNIT_PRICE_COP = 1_000                       # shelf price per unit
DAILY_UNITS_LOW, DAILY_UNITS_HIGH = 13_500, 16_500
MATURITY_MEAN, MATURITY_SD = 3.2, 0.7        # average shelf maturity, 1-5 scale
LOW_MATURITY_THRESHOLD = 2.5                 # below this, shoppers reject the fruit
REJECTION_RATE_NOW = 0.15                    # demand lost on a low-maturity day, today
REJECTION_RATE_GRADED = 0.03                 # same day, with automated grading
MACHINE_COST_COP = 150_000_000
DAILY_OPERATING_COST_COP = 150_000
DAYS = 365

DATA_PATH = Path("data/avocado_simulated_data.csv")
RAW_URL = ("https://raw.githubusercontent.com/Helian1505/Avocado_Sales_Optimization/"
           "main/data/avocado_simulated_data.csv")

# %% [markdown]
# ## 1. The model
#
# Two functions carry the whole analysis: one builds the two scenarios from a day-level
# table of demand and shelf maturity, the other turns a year into an investment case.

# %%
def add_scenarios(df: pd.DataFrame) -> pd.DataFrame:
    """Attach today's scenario and the graded scenario to a demand/maturity frame."""
    df = df.copy()
    low = df["Gondola_Avg_Maturity"] < LOW_MATURITY_THRESHOLD
    df["Maturity_Impact_Ratio"] = np.where(low, REJECTION_RATE_NOW, 0.0)
    df["Optimized_Impact_Ratio"] = np.where(low, REJECTION_RATE_GRADED, 0.0)
    df["Units_Lost"] = df["Base_Demand"] * df["Maturity_Impact_Ratio"]
    df["Units_Lost_Optimized"] = df["Base_Demand"] * df["Optimized_Impact_Ratio"]
    df["Units_Recovered"] = df["Units_Lost"] - df["Units_Lost_Optimized"]
    return df


@dataclass(frozen=True)
class Case:
    """The financial case for one trading year, in COP."""
    revenue_lost_now: float
    revenue_lost_graded: float
    recovered: float
    operating_cost: float
    net_benefit: float
    roi_pct: float
    payback_months: float
    low_maturity_days: int


def build_case(df: pd.DataFrame) -> Case:
    lost_now = df["Units_Lost"].sum() * UNIT_PRICE_COP
    lost_graded = df["Units_Lost_Optimized"].sum() * UNIT_PRICE_COP
    recovered = lost_now - lost_graded
    operating = DAILY_OPERATING_COST_COP * DAYS
    net = recovered - operating
    return Case(
        revenue_lost_now=lost_now,
        revenue_lost_graded=lost_graded,
        recovered=recovered,
        operating_cost=operating,
        net_benefit=net,
        roi_pct=net / MACHINE_COST_COP * 100,
        payback_months=MACHINE_COST_COP / (net / 12) if net > 0 else float("inf"),
        low_maturity_days=int((df["Gondola_Avg_Maturity"] < LOW_MATURITY_THRESHOLD).sum()),
    )


def simulate_year(seed: int | None = None) -> pd.DataFrame:
    """Draw an alternative trading year. Seeded, so section 4 is reproducible."""
    rs = np.random.RandomState(seed)
    return add_scenarios(pd.DataFrame({
        "Base_Demand": rs.randint(DAILY_UNITS_LOW, DAILY_UNITS_HIGH, DAYS),
        "Gondola_Avg_Maturity": rs.normal(MATURITY_MEAN, MATURITY_SD, DAYS).clip(1, 5).round(1),
    }))


def load_published_year() -> pd.DataFrame:
    """Load the committed year — the canonical dataset behind every headline figure."""
    source = DATA_PATH if DATA_PATH.exists() else RAW_URL
    raw = pd.read_csv(source, parse_dates=["Date"])
    return add_scenarios(raw[["Date", "Base_Demand", "Gondola_Avg_Maturity"]])


year = load_published_year()
case = build_case(year)
year.head()
# Out:
#         Date  Base_Demand  Gondola_Avg_Maturity  Maturity_Impact_Ratio  \
# 0 2025-01-01        15640                  2.50                   0.00
# 1 2025-01-02        15161                  2.90                   0.00
# 2 2025-01-03        15467                  4.10                   0.00
# 3 2025-01-04        14745                  3.10                   0.00
# 4 2025-01-05        14065                  3.20                   0.00
#
#    Optimized_Impact_Ratio  Units_Lost  Units_Lost_Optimized  Units_Recovered
# 0                    0.00        0.00                  0.00             0.00
# 1                    0.00        0.00                  0.00             0.00
# 2                    0.00        0.00                  0.00             0.00
# 3                    0.00        0.00                  0.00             0.00
# 4                    0.00        0.00                  0.00             0.00

# %% [markdown]
# ## 2. Where the revenue leaks
#
# Rejection is not gradual: it switches on below maturity 2.5 and is zero above it. That
# threshold is the whole reason a grading machine can work — the days that need fixing are
# identifiable in advance.

# %%
print(f"Days below the maturity threshold : {case.low_maturity_days} of {DAYS}")
print(f"Units lost to rejection           : {year.Units_Lost.sum():,.0f}")
print(f"Share of annual demand lost       : {year.Units_Lost.sum() / year.Base_Demand.sum():.2%}")
print(f"Revenue lost (COP)                : ${case.revenue_lost_now:,.0f}")
# Out:
# Days below the maturity threshold : 54 of 365
# Units lost to rejection           : 123,322
# Share of annual demand lost       : 2.25%
# Revenue lost (COP)                : $123,321,900

# %%
# ── Chart style: dark surface, low chrome, one accent reserved for the result ───
SURFACE, GRID, LINE = "#0f1011", "#23252a", "#383b3f"
PAPER, MIST, FOG, ASH = "#ffffff", "#d0d6e0", "#8a8f98", "#62666d"
NEUTRAL, NEGATIVE, RESULT = "#62666d", "#eb5757", "#e4f222"

matplotlib.rcParams.update({
    "font.family": ["Inter", "DejaVu Sans"], "figure.facecolor": SURFACE,
    "axes.facecolor": SURFACE, "axes.labelcolor": FOG, "text.color": MIST,
    "xtick.color": FOG, "ytick.color": ASH, "xtick.major.size": 0, "ytick.major.size": 0,
    "grid.color": GRID, "grid.linewidth": 1, "savefig.facecolor": SURFACE,
    "figure.dpi": 100, "figure.figsize": (14.4, 8.08),
})
Path("images").mkdir(exist_ok=True)


def frame(ax):
    for s in ax.spines.values():
        s.set_visible(False)
    ax.grid(axis="y", zorder=0)


def titles(fig, eyebrow, headline, sub, size=22):
    fig.text(0.075, 0.925, eyebrow, fontsize=12, color=FOG, family="monospace")
    fig.text(0.075, 0.855, headline, fontsize=size, color=PAPER)
    fig.text(0.075, 0.805, sub, fontsize=13, color=FOG)

# %%
fig, ax = plt.subplots()
fig.subplots_adjust(left=0.075, right=0.975, top=0.76, bottom=0.12)

lost = year["Units_Lost"] > 0
ax.scatter(year.loc[~lost, "Gondola_Avg_Maturity"], year.loc[~lost, "Units_Lost"], s=46,
           color=NEUTRAL, alpha=.75, edgecolors=SURFACE, linewidths=1.5, zorder=3, label="Normal day")
ax.scatter(year.loc[lost, "Gondola_Avg_Maturity"], year.loc[lost, "Units_Lost"], s=52,
           color=NEGATIVE, alpha=.9, edgecolors=SURFACE, linewidths=1.5, zorder=4, label="Units rejected")
ax.axvline(LOW_MATURITY_THRESHOLD, color=ASH, lw=1, ls=(0, (3, 3)), zorder=2)
ax.set_ylim(-170, year["Units_Lost"].max() * 1.26)
ax.text(LOW_MATURITY_THRESHOLD + 0.09, year["Units_Lost"].max() * 1.13,
        f"← rejection only starts below maturity {LOW_MATURITY_THRESHOLD}",
        ha="left", fontsize=12.5, color=MIST)
ax.text(5.02, 70, "every day above the threshold loses nothing", ha="right", fontsize=12, color=ASH)
ax.set_xlabel("Average shelf maturity (1–5)", fontsize=13, labelpad=12)
ax.set_ylabel("Units lost to customer rejection", fontsize=13, labelpad=12)
leg = ax.legend(loc="upper right", frameon=False, fontsize=12.5, handletextpad=.4)
for t in leg.get_texts():
    t.set_color(MIST)
frame(ax)
titles(fig, "AVOCADO QUALITY ROI · ROOT CAUSE",
       "Losses are all-or-nothing: zero above maturity 2.5, ~2,300 units a day below it",
       f"{case.low_maturity_days} of {DAYS} days fell below the threshold in the year analysed")
fig.savefig("images/maturity_vs_loss.png")
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# ...

# %% [markdown]
# ## 3. The business case
#
# The gross saving is not the benefit. Grading does not eliminate rejection — it cuts it from
# 15% to 3% — and the machine costs COP 150k a day to run. The bridge below carries both
# deductions, so the number at the end is the one a CFO would actually approve.

# %%
m = 1e6
steps = [
    ("Revenue lost\ntoday",        0,                     case.revenue_lost_now / m,    NEUTRAL,  f"{case.revenue_lost_now/m:,.1f}",    "total"),
    ("Still lost with\ngrading tech", case.recovered / m, case.revenue_lost_graded / m, NEGATIVE, f"−{case.revenue_lost_graded/m:,.1f}", "delta"),
    ("Revenue\nrecovered",         0,                     case.recovered / m,           NEUTRAL,  f"{case.recovered/m:,.1f}",           "total"),
    ("Annual\noperating cost",     case.net_benefit / m,  case.operating_cost / m,      NEGATIVE, f"−{case.operating_cost/m:,.1f}",     "delta"),
    ("Net annual\nbenefit",        0,                     case.net_benefit / m,         RESULT,   f"{case.net_benefit/m:,.1f}",         "result"),
]

fig, ax = plt.subplots()
fig.subplots_adjust(left=0.075, right=0.975, top=0.76, bottom=0.14)
w = 0.56
for i, (label, bottom, height, colour, text, kind) in enumerate(steps):
    ax.add_patch(FancyBboxPatch((i - w / 2, bottom), w, height,
                                boxstyle="round,pad=0,rounding_size=0.035",
                                mutation_aspect=height / w * 0.06, fc=colour, ec="none", zorder=3))
    top = bottom + height
    ax.text(i, top + 3, text, ha="center", va="bottom", fontsize=19 if kind == "result" else 16,
            color=MIST if kind == "delta" else PAPER, zorder=4)
    if i < len(steps) - 1:                      # dashed carry-over line
        level = bottom if kind == "delta" else top
        ax.plot([i + w / 2, i + 1 - w / 2], [level, level], color=ASH, lw=1, ls=(0, (3, 3)), zorder=2)

ax.set_xlim(-0.6, len(steps) - 0.4)
ax.set_ylim(0, case.revenue_lost_now / m * 1.14)
ax.set_xticks(range(len(steps)))
ax.set_xticklabels([s[0] for s in steps], fontsize=13.5, color=FOG, linespacing=1.35)
ax.tick_params(axis="x", pad=14)
ax.tick_params(axis="y", pad=10)
frame(ax)
ax.axhline(0, color=LINE, lw=1, zorder=4)
ax.text(-0.075, 1.0, "COP M", transform=ax.transAxes, fontsize=11, color=ASH, va="bottom", family="monospace")
titles(fig, "AVOCADO QUALITY ROI · ANNUAL BUSINESS CASE",
       f"Grading technology turns COP {case.revenue_lost_now/m:,.0f}M of lost sales into {case.net_benefit/m:,.1f}M net benefit a year",
       f"COP {MACHINE_COST_COP/m:,.0f}M investment  ·  {case.roi_pct:,.2f}% annual ROI  ·  {case.payback_months:,.0f}-month payback"
       f"  ·  rejection falls from {REJECTION_RATE_NOW:.0%} to {REJECTION_RATE_GRADED:.0%} on low-maturity days")
fig.savefig("images/business_case.png")
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# ...

# %%
print("--- ANNUAL CASE, YEAR ANALYSED -------------------------")
print(f"1. Revenue recovered (gross) : ${case.recovered:,.0f} COP")
print(f"2. Annual operating cost     : ${case.operating_cost:,.0f} COP")
print(f"3. Net annual benefit        : ${case.net_benefit:,.0f} COP")
print(f"   Annual ROI                : {case.roi_pct:.2f} %")
print(f"   Payback period            : {case.payback_months:.1f} months")
# Out:
# --- ANNUAL CASE, YEAR ANALYSED -------------------------
# 1. Revenue recovered (gross) : $98,657,520 COP
# 2. Annual operating cost     : $54,750,000 COP
# 3. Net annual benefit        : $43,907,520 COP
#    Annual ROI                : 29.27 %
#    Payback period            : 41.0 months

# %% [markdown]
# ## 4. How much of that is the model, and how much is the year?
#
# The figures above describe **one** trading year. Shelf maturity is drawn from a
# distribution, so a different year has a different number of low-maturity days — and the
# whole case moves with it. Reporting a single ROI as if it were a fact would be the real
# error in this analysis.
#
# So: re-run the model over 3,000 independent years and look at the spread.

# %%
def sensitivity(n_years: int = 3_000) -> pd.DataFrame:
    rows = []
    for seed in range(n_years):
        c = build_case(simulate_year(seed))
        rows.append({"roi_pct": c.roi_pct, "net_benefit": c.net_benefit,
                     "revenue_lost_now": c.revenue_lost_now,
                     "payback_months": c.payback_months,
                     "low_maturity_days": c.low_maturity_days})
    return pd.DataFrame(rows)


sims = sensitivity()

# A year with no net benefit never pays back; keep it out of the quantiles rather than
# letting an infinity poison them.
finite = sims.replace(np.inf, np.nan)
summary = finite[["revenue_lost_now", "net_benefit", "roi_pct", "payback_months"]].quantile([.1, .5, .9])
summary.index = ["p10", "median", "p90"]
summary
# Out:
#         revenue_lost_now   net_benefit  roi_pct  payback_months
# p10        97,746,810.00 23,447,448.00    15.63           33.46
# median    116,250,150.00 38,250,120.00    25.50           47.03
# p90       135,683,820.00 53,797,056.00    35.86           76.50

# %%
fig, ax = plt.subplots()
fig.subplots_adjust(left=0.075, right=0.975, top=0.76, bottom=0.14)

p10, p50, p90 = np.percentile(sims.roi_pct, [10, 50, 90])
counts, bins, patches = ax.hist(sims.roi_pct, bins=46, color=NEUTRAL,
                                edgecolor=SURFACE, linewidth=1.2, zorder=3)
for left, patch in zip(bins[:-1], patches):          # recede the tails
    if left < p10 or left >= p90:
        patch.set_facecolor("#3a3d42")

top = counts.max()
ax.axvline(p50, color=MIST, lw=1, ls=(0, (3, 3)), zorder=5)
ax.text(p50, top * 1.06, f"median {p50:,.1f}%", ha="center", fontsize=13, color=MIST, zorder=6)
ax.axvline(case.roi_pct, color=RESULT, lw=1.5, zorder=5)
ax.text(case.roi_pct, top * 1.13, f"year analysed {case.roi_pct:,.2f}%", ha="center",
        fontsize=13, color=RESULT, zorder=6)
ax.axvspan(p10, p90, color="#ffffff", alpha=.03, zorder=1)
ax.text(0.012, 0.95, f"80% of years fall between {p10:,.1f}% and {p90:,.1f}%",
        transform=ax.transAxes, fontsize=12.5, color=FOG, va="top", zorder=6)

ax.set_ylim(0, top * 1.22)
ax.set_xlabel("Annual ROI (%)", fontsize=13, labelpad=12)
ax.set_ylabel(f"Simulated years (n = {len(sims):,})", fontsize=13, labelpad=12)
ax.tick_params(axis="x", pad=8, labelsize=11.5)
ax.tick_params(axis="y", pad=8, labelsize=11.5)
frame(ax)
titles(fig, "AVOCADO QUALITY ROI · SENSITIVITY",
       f"Profitable in {(sims.net_benefit > 0).mean():.1%} of simulated years, but only "
       f"{(sims.payback_months <= 60).mean():.0%} pay back within five",
       "Each of the 3,000 years re-draws daily demand and shelf maturity from the same assumptions",
       size=21)
fig.savefig("images/roi_distribution.png")
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Inter' not found.
# ...

# %%
pct = (sims.roi_pct < case.roi_pct).mean()
print(f"Year analysed sits at percentile {pct:.0%} of the simulated distribution")
print(f"Median ROI            : {sims.roi_pct.median():.2f} %   (p10 {np.percentile(sims.roi_pct,10):.2f} – p90 {np.percentile(sims.roi_pct,90):.2f})")
print(f"Median payback        : {sims.payback_months.median():.1f} months   (p10 {np.percentile(sims.payback_months,10):.1f} – p90 {np.percentile(sims.payback_months,90):.1f})")
print(f"Years with a net loss : {(sims.net_benefit <= 0).mean():.1%}")
print(f"Years paying back in 5 years or less: {(sims.payback_months <= 60).mean():.0%}")
# Out:
# Year analysed sits at percentile 67% of the simulated distribution
# Median ROI            : 25.50 %   (p10 15.63 – p90 35.86)
# Median payback        : 47.1 months   (p10 33.5 – p90 76.8)
# Years with a net loss : 0.1%
# Years paying back in 5 years or less: 76%

# %% [markdown]
# ## 5. Recommendation
#
# **Make the investment, and size the expectation correctly.**
#
# - The mechanism is real and identifiable: losses appear only below maturity 2.5, so the
#   days worth acting on can be flagged in advance.
# - The year analysed returns **29.27% ROI with a 41-month payback**. That is a normal draw,
#   not a best case — it sits at the 67th percentile of 3,000 simulated years.
# - Across those years the case is profitable **99.9%** of the time, with a **median ROI of
#   25.5%** (p10–p90: 15.6%–35.9%) and a **median payback of 47 months**.
# - The risk is not losing money, it is **waiting for it**: only ~76% of years pay back within
#   five years. If the approval threshold is a five-year payback, this is a decision made
#   under uncertainty, and it should be presented that way rather than as a single number.
#
# **What would change the answer:** the rejection rate on low-maturity days (15%) and the
# graded rate (3%) are assumptions, not measurements. Before committing capital, they are
# worth measuring in one store for a quarter — they move the result more than anything else
# in the model.
